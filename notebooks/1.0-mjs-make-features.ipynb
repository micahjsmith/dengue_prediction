# %%
import logging
logging.basicConfig(level=logging.DEBUG)

# %%
from dengue_prediction.data.make_dataset import load_data
from dengue_prediction.features.build_features import build_features

# %%
X_df, y_df = load_data()

# %%
X_df.head()
# Out:
#                      week_start_date   ndvi_ne   ndvi_nw   ndvi_se   ndvi_sw  \
# city year weekofyear
# sj   1990 18              1990-04-30  0.122600  0.103725  0.198483  0.177617
#           19              1990-05-07  0.169900  0.142175  0.162357  0.155486
#           20              1990-05-14  0.032250  0.172967  0.157200  0.170843
#           21              1990-05-21  0.128633  0.245067  0.227557  0.235886
#           22              1990-05-28  0.196200  0.262200  0.251200  0.247340
#
#                       precipitation_amt_mm  reanalysis_air_temp_k  \
# city year weekofyear
# sj   1990 18                         12.42             297.572857
#           19                         22.82             298.211429
#           20                         34.54             298.781429
#           21                         15.36             298.987143
#           22                          7.52             299.518571
#
# ...

# %%
X1 = build_features()
X1[:5]
# Out:
# INFO:dengue_prediction.features.build_features:Building features...
# DEBUG:dengue_prediction.features.feature:Converting using approach 'identity'
# DEBUG:dengue_prediction.features.feature:Converting using approach 'DataFrame'
# DEBUG:dengue_prediction.features.feature:Converting using approach 'identity'
# DEBUG:dengue_prediction.features.feature:Converting using approach 'DataFrame'
# DEBUG:dengue_prediction.features.feature:Converting using approach 'identity'
# DEBUG:dengue_prediction.features.feature:Converting using approach 'DataFrame'
# DEBUG:dengue_prediction.features.feature:Converting using approach 'identity'
# DEBUG:dengue_prediction.features.feature:Converting using approach 'DataFrame'
# DEBUG:dengue_prediction.features.feature:Converting using approach 'identity'
# DEBUG:dengue_prediction.features.feature:Converting using approach 'identity'
# DEBUG:dengue_prediction.features.feature:Converting using approach 'DataFrame'
# ...
